# %%
import pandas as pd

# %%
pip install selenium
# Out:
# Requirement already satisfied: selenium in /opt/anaconda3/lib/python3.9/site-packages (4.2.0)
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in /opt/anaconda3/lib/python3.9/site-packages (from selenium) (1.26.9)
# Requirement already satisfied: trio~=0.17 in /opt/anaconda3/lib/python3.9/site-packages (from selenium) (0.21.0)
# Requirement already satisfied: trio-websocket~=0.9 in /opt/anaconda3/lib/python3.9/site-packages (from selenium) (0.9.2)
# Requirement already satisfied: async-generator>=1.9 in /opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sortedcontainers in /opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: outcome in /opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: wsproto>=0.14 in /opt/anaconda3/lib/python3.9/site-packages (from trio-websocket~=0.9->selenium) (1.1.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /opt/anaconda3/lib/python3.9/site-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pyOpenSSL>=0.14 in /opt/anaconda3/lib/python3.9/site-packages (from urllib3[secure,socks]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in /opt/anaconda3/lib/python3.9/site-packages (from urllib3[secure,socks]~=1.26->selenium) (3.4.8)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.9/site-packages (from urllib3[secure,socks]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.9/site-packages (from cryptography>=1.3.4->urllib3[secure,socks]~=1.26->selenium) (1.15.0)
# Requirement already satisfied: six>=1.5.2 in /opt/anaconda3/lib/python3.9/site-packages (from pyOpenSSL>=0.14->urllib3[secure,socks]~=1.26->selenium) (1.16.0)
# Requirement already satisfied: h11<1,>=0.9.0 in /opt/anaconda3/lib/python3.9/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=1.3.4->urllib3[secure,socks]~=1.26->selenium) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
import selenium
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")
import time

# %%
driver=webdriver.Chrome("/usr/local/bin/chromedriver")

# %%
driver=webdriver.Chrome("chromedriver")
time.sleep(2)

# %%
driver.get("https://www.naukri.com/")

# %%
search_designation=driver.find_element_by_class_name("suggestor-input")
search_designation.send_keys("Data Analyst")
search_location=driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[3]/div/div/div[5]/div/div/div/input")
search_location.send_keys("Bangalore")
search_button=driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[3]/div/div/div[6]")
search_button.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience=[]
##title=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
for i in driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']"):
    job_title.append(i.text)
job_title[0:10]
for i in driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']"):
    company_name.append(i.text)
company_name[0:10]
for i in driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience']/span"):
    experience.append(i.text)
experience[0:10]
for i in driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span[1]"):
    job_location.append(i.text)
job_location[0:10]    
jobs=pd.DataFrame()
jobs['Job_Title']=job_title
jobs['Company']=company_name
jobs['Experience']=experience
jobs['Location']=job_location
jobs[0:10]
# Out:
#                                            Job_Title                 Company  \
# 0                                Senior Data Analyst                Liventus
# 1                                    Data Analyst II                  Cerner
# 2  Legal Operations Data Analyst (I P Invoice Foc...       Applied Materials
# 3                                   Data Analyst 4.4                     ANZ
# 4                  Data Analyst - Business & Digital          MilliporeSigma
# 5                              Business Data Analyst      NXP Semiconductors
# 6          EY GDS Data Analyst-Finland based project                      EY
# 7    Business Analyst/Data analyst - Payments Domain                     CGI
# 8                                       Data Analyst                 Apisero
# 9         Business & Data Analyst - Alteryx (London)  Imaginative Brains LLP
#
#   Experience                                           Location
# 0    5-8 Yrs                                             Remote
# 1    2-4 Yrs                                Bangalore/Bengaluru
# 2    4-7 Yrs                                Bangalore/Bengaluru
# 3    1-4 Yrs                                Bangalore/Bengaluru
# 4    4-9 Yrs                                Bangalore/Bengaluru
# 5    2-5 Yrs                                Bangalore/Bengaluru
# 6    0-1 Yrs                                Bangalore/Bengaluru
# 7    4-8 Yrs  Bangalore/Bengaluru, Hyderabad/Secunderabad, P...
# 8    4-9 Yrs                                Bangalore/Bengaluru
# 9   5-10 Yrs  Bangalore/Bengaluru, Delhi / NCR, Mumbai (All ...

# %%
driver.get("https://www.naukri.com/")

# %%
search_designation=driver.find_element_by_class_name("suggestor-input")
search_designation.send_keys("Data Scientist")
search_location=driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[3]/div/div/div[5]/div/div/div/input")
search_location.send_keys("Bangalore")
search_button=driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[3]/div/div/div[6]")
search_button.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience=[]
##title=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
for i in driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']"):
    job_title.append(i.text)
job_title[0:10]
for i in driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']"):
    company_name.append(i.text)
company_name[0:10]
for i in driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience']/span"):
    experience.append(i.text)
experience[0:10]
for i in driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span[1]"):
    job_location.append(i.text)
job_location[0:10]    
jobs=pd.DataFrame()
jobs['Job_Title']=job_title
jobs['Company']=company_name
jobs['Experience']=experience
jobs['Location']=job_location
jobs[0:10]
# Out:
# Empty DataFrame
# Columns: [Job_Title, Company, Experience, Location]
# Index: []

# %%
from selenium.common.exceptions import NoSuchElementException
driver.get("https://www.flipkart.com/")
login=driver.find_element_by_xpath("//button[@class='_2KpZ6l _2doB4z']")
try:
    login.click
except:
    pass

# %%
search_sunglasses=driver.find_element_by_class_name("_3704LK")
search_sunglasses.send_keys("sunglasses")

# %%
search_button=driver.find_element_by_class_name("_34RNph")
search_button.click()

# %%
from selenium.common.exceptions import ElementNotInteractableException
for i in range(0,3):
    nxt_button =driver.find_elements_by_xpath("//a[@class='_1LKTO3']")
    try:

        driver.get(nxt_button[1].get_attribute('href'))

    except:

        driver.get(nxt_button[0].get_attribute('href'))
Brand=[]
for i in driver.find_elements_by_xpath("//div[@class='_2WkVRV']"):
    Brand.append(i.text)
description=[]
for i in driver.find_elements_by_xpath("//a[@class='IRpwTa']"):
    description.append(i.text)
price=[]
for i in driver.find_elements_by_xpath("//div[@class='_30jeq3']"):
    price.append(i.text)       
sunglasses=pd.DataFrame()
sunglasses['Brand']=Brand
sunglasses['description']=description
sunglasses['Price']=price
sunglasses[0:100]
# Out:
#                         Brand  \
# 0                  Lee Topper
# 1                    Roadster
# 2                      GANSTA
# 3                 john jacobs
# 4                Singco India
# 5                   ROYAL SON
# 6                  Lee Topper
# 7              ROZZETTA CRAFT
# 8               VINCENT CHASE
# 9                   ROYAL SON
# 10             ROZZETTA CRAFT
# 11                     AISLIN
# 12             ROZZETTA CRAFT
# 13                   Fastrack
# 14                     GANSTA
# 15             ROZZETTA CRAFT
# 16                  ROYAL SON
# 17                  ROYAL SON
# 18             kingsunglasses
# 19              VINCENT CHASE
# 20                   Poloport
# 21                     GANSTA
# 22                     PIRASO
# 23              VINCENT CHASE
# 24                   Fastrack
# 25                      WROGN
# 26                     SUNBEE
# 27              VINCENT CHASE
# 28                     PIRASO
# 29                   Fastrack
# 30             ROZZETTA CRAFT
# 31                  ROYAL SON
# 32              VINCENT CHASE
# 33                       hipe
# 34                     GANSTA
# 35              VINCENT CHASE
# 36                    Urbanic
# 37                         Mi
# 38  United Colors of Benetton
# 39              VINCENT CHASE
#
#                                           description   Price
# 0        UV Protection Cat-eye Sunglasses (Free Size)    ₹299
# 1                  UV Protection Oval Sunglasses (58)    ₹649
# 2           UV Protection Rectangular Sunglasses (60)    ₹242
# 3                 UV Protection Round Sunglasses (53)  ₹3,500
# 4   Gradient, Toughened Glass Lens, Others Retro S...    ₹664
# 5    Polarized, UV Protection Aviator Sunglasses (58)    ₹711
# 6   Riding Glasses, Night Vision Wrap-around Sungl...    ₹276
# 7   UV Protection, Gradient Round Sunglasses (Free...    ₹399
# 8     by Lenskart UV Protection Round Sunglasses (58)    ₹949
# 9                    Mirrored Aviator Sunglasses (58)    ₹379
# 10         UV Protection Round Sunglasses (Free Size)    ₹359
# 11  UV Protection, Gradient Cat-eye, Round Sunglas...    ₹448
# 12  UV Protection, Riding Glasses Rectangular Sung...    ₹404
# 13      Polarized Retro Square Sunglasses (Free Size)    ₹639
# 14  Gradient, UV Protection Retro Square Sunglasse...    ₹233
# 15     UV Protection Spectacle Sunglasses (Free Size)    ₹399
# 16                UV Protection Round Sunglasses (50)    ₹449
# 17   UV Protection, Gradient Wayfarer Sunglasses (55)    ₹217
# 18  UV Protection, Night Vision Wayfarer Sunglasse...    ₹299
# 19          UV Protection Rectangular Sunglasses (52)    ₹649
# 20      UV Protection Wayfarer Sunglasses (Free Size)    ₹281
# 21  UV Protection, Riding Glasses Aviator Sunglass...    ₹314
# 22           UV Protection Over-sized Sunglasses (64)    ₹439
# 23  by Lenskart Polarized, UV Protection Round Sun...    ₹849
# 24       UV Protection Aviator Sunglasses (Free Size)    ₹699
# 25                    Polarized Round Sunglasses (44)    ₹899
# 26  UV Protection, Polarized, Mirrored Wayfarer Su...    ₹268
# 27  by Lenskart Polarized, UV Protection Cat-eye S...    ₹949
# 28              UV Protection Aviator Sunglasses (50)    ₹345
# 29              Gradient Round Sunglasses (Free Size)  ₹1,599
# 30  UV Protection Retro Square Sunglasses (Free Size)    ₹499
# 31             Polarized Retro Square Sunglasses (61)    ₹699
# 32  by Lenskart Polarized, UV Protection Retro Squ...    ₹949
# 33  Mirrored, Gradient, Riding Glasses Round Sungl...    ₹210
# 34    UV Protection, Gradient Aviator Sunglasses (57)    ₹242
# 35  by Lenskart Polarized, UV Protection Aviator S...    ₹949
# 36         Others Retro Square Sunglasses (Free Size)    ₹619
# 37          Polarized Wayfarer Sunglasses (Free Size)    ₹849
# 38      Mirrored, UV Protection Round Sunglasses (57)    ₹999
# 39          UV Protection Rectangular Sunglasses (50)    ₹649

# %%
start=0

end=4

for page in range(start,end):#for loop for scrapping 4 page

    brand=driver.find_elements_by_class_name('_2WkVRV')#scraping brands name by class name='_2WkVRV'

    for i in brands:

        brand.append(i.text)#appending the text in Brand list

        nxt_button=driver.find_elements_by_xpath("//a[@class='_1LKTO3']")#scraping the list of buttons from the page

    try:

        driver.get(nxt_button[1].get_attribute('href'))#getting the link from the list for next page

    except:

        driver.get(nxt_button[0].get_attribute('href'))
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Input In [188], in <cell line: 5>()
#       7 brand=driver.find_elements_by_class_name('_2WkVRV')#scraping brands name by class name='_2WkVRV'
#       9 for i in brands:
# ---> 11     brand.append(i.text)#appending the text in Brand list
#      13     nxt_button=driver.find_elements_by_xpath("//a[@class='_1LKTO3']")#scraping the list of buttons from the page
#      15 try:
#
# File /opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webelement.py:85, in WebElement.text(self)
#      82 @property
#      83 def text(self) -> str:
#      84     """The text of the element."""
# ---> 85     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#
# File /opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webelement.py:773, in WebElement._execute(self, command, params)
#     771     params = {}
#     772 params['id'] = self._id
# --> 773 return self._parent.execute(command, params)
#
# File /opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:430, in WebDriver.execute(self, driver_command, params)
#     428 response = self.command_executor.execute(driver_command, params)
#     429 if response:
# --> 430     self.error_handler.check_response(response)
#     431     response['value'] = self._unwrap_value(
#     432         response.get('value', None))
#     433     return response
#
# File /opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=103.0.5060.53)
# Stacktrace:
# 0   chromedriver                        0x0000000104831d14 chromedriver + 3792148
# 1   chromedriver                        0x00000001047c8828 chromedriver + 3360808
# 2   chromedriver                        0x00000001044c90b8 chromedriver + 217272
# 3   chromedriver                        0x00000001044cbae8 chromedriver + 228072
# 4   chromedriver                        0x00000001044cb950 chromedriver + 227664
# 5   chromedriver                        0x00000001044cbb84 chromedriver + 228228
# 6   chromedriver                        0x00000001044f40f0 chromedriver + 393456
# 7   chromedriver                        0x00000001044ef614 chromedriver + 374292
# 8   chromedriver                        0x0000000104521a60 chromedriver + 580192
# 9   chromedriver                        0x00000001044ee318 chromedriver + 369432
# 10  chromedriver                        0x00000001048071e8 chromedriver + 3617256
# 11  chromedriver                        0x000000010480b678 chromedriver + 3634808
# 12  chromedriver                        0x000000010480fc6c chromedriver + 3652716
# 13  chromedriver                        0x000000010480c110 chromedriver + 3637520
# 14  chromedriver                        0x00000001047ea7ac chromedriver + 3499948
# 15  chromedriver                        0x0000000104823bf0 chromedriver + 3734512
# 16  chromedriver                        0x0000000104823d54 chromedriver + 3734868
# 17  chromedriver                        0x0000000104838558 chromedriver + 3818840
# 18  libsystem_pthread.dylib             0x00000001bcab1240 _pthread_start + 148
# 19  libsystem_pthread.dylib             0x00000001bcaac024 thread_start + 8

# %%
driver.get("https://www.flipkart.com/")

# %%
from selenium.common.exceptions import ElementNotInteractableException
##from selenium.common.exceptions import NoSuchElementException
search=driver.find_element_by_class_name("_3704LK")
search.send_keys("Iphone11")
search_button=driver.find_element_by_class_name("_34RNph")
search_button.click()
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb/p/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZE3ENS&marketplace=FLIPKART&q=Iphone11&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=Search&iid=97f2789a-6842-41a7-aa11-7ccf420b3fd0.MOBFWQ6BXGJCEYNY.SEARCH&ppt=sp&ppn=sp&ssid=2udu55ykj40000001656591445650&qH=6d60e39954c2077c")
all_reviews=driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[6]/div/a/div")
all_reviews.click()

# %%
from selenium.common.exceptions import ElementNotInteractableException
for i in range(10):
    nxt_button =driver.find_elements_by_xpath("//a[@class='_1LKTO3']")
    try:

        driver.get(nxt_button[1].get_attribute('href'))

    except:

        driver.get(nxt_button[0].get_attribute('href'))
    rating=[]
for i in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']"):
    rating.append(i.text)
rating
description=[]
for i in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
    description.append(i.text)
brief=[]
for i in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
    brief.append(i.text)
##next_button=driver.find_element_by_xpath("//span[@class='_22Tduf']")
##next_button.click()
time.sleep(5)
   
reviews=pd.DataFrame()
reviews['Rating']=rating
reviews['description']=description
reviews['Brief']=brief
reviews[0:100]
# Out:
#   Rating            description  \
# 0      5  Mind-blowing purchase
# 1      5                Awesome
# 2      5      Terrific purchase
# 3      5                Awesome
# 4      3         Decent product
# 5      5    Best in the market!
# 6      5  Mind-blowing purchase
# 7      5         Classy product
# 8      4              Wonderful
# 9      4   Good quality product
#
#                                                Brief
# 0  Absolutely powerful gadget. Loved it’s look! S...
# 1  Can’t beat the software and hardware integrati...
# 2  I use a Note10+ and have been using both iOS a...
# 3  The phone is completely good\nAs far as camera...
# 4  Everything u ll like it when u use this iPhone...
# 5  Really very nice... my dad gifted me really I ...
# 6  Released in 2019\nIn 2021 still the best in se...
# 7  I got this phone for good price hence 5 star f...
# 8  I genuinely liked it. One of the best mobile p...
# 9  Awesome camera, smooth and fast UI, display is...

# %%
driver.get("https://www.myntra.com/shoes") - while clicking inspect not coming up

# %%
driver.get("https://www.amazon.in/")

# %%
from selenium.common.exceptions import ElementNotInteractableException
search=driver.find_element_by_id("twotabsearchtextbox")
search.send_keys("Laptop")
search_button=driver.find_element_by_id("nav-search-submit-button")
search_button.click()
check_box=driver.find_element_by_xpath("//*[@id='p_n_feature_thirteen_browse-bin/12598163031']/span/a/span")
check_box.click()

# %%
title=[]
for i in driver.find_elements_by_xpath("//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']"):
    title.append(i.text)
title[0:10]
rating=[]
for i in driver.find_elements_by_xpath("//li[@class='a-icon a-icon-star-small a-star-small-4-5 aok-align-bottom']"):
    rating.append(i.text)
rating
price=[]
for i in driver.find_elements_by_xpath("//span[@class='a-price-whole']"):
    price.append(i.text)
price
laptop=pd.DataFrame()
laptop['title']=title
##laptop['rating']=rating
laptop['price']=price
laptop=laptop.head(10)
laptop
# Out:
#                                                title   price
# 0  LG Gram 17 Intel Evo 11th Gen i7 Thin & Light ...  88,990
# 1  ASUS VivoBook 14 (2021), 14-inch (35.56 cms) F...  55,499
# 2  Hp Pavilion X360 11Th Gen Intel Core I7 14 Inc...  84,559
# 3  Lenovo ThinkBook 15 Intel 11th Gen Core i7 15....  86,990
# 4  ASUS TUF Gaming F15 (2021), 15.6" (39.62 cms) ...  89,990
# 5  Samsung Galaxy Book2 Intel 12th Gen core i7 39...  79,990
# 6  Lenovo IdeaPad 5 Pro 11th Gen Intel Core i7 14...  74,011
# 7  Lenovo IdeaPad Flex 5 Intel Core i7 11th Gen 1...  81,100
# 8  HP Pavilion 14 12th Gen Intel Core i7 16GB SDR...  86,990
# 9  Fujitsu UH-X 11th Gen Intel Core i7 13.3” FHD ...  81,590

# %%
driver.get("https://www.ambitionbox.com/")

# %%
salaries=driver.find_element_by_xpath("/html/body/section[3]/div/div[1]/a")
salaries.click()

# %%
job=driver.find_element_by_id("jobProfileSearchbox")
job.send_keys("Data Scientist")

# %%
DS=driver.find_element_by_xpath("//*[@id='salaries']/main/section[1]/div[2]/div[1]/span/div/div/div[1]/div/div/p")
DS.click()

# %%
company=[]
for i in driver.find_elements_by_xpath("//div[@class='company-info-wrapper']"):
    company.extend(i.text)
company
# Out:
# ['W',
#  'a',
#  'l',
#  'm',
#  'a',
#  'r',
#  't',
#  '\n',
#  'D',
#  'a',
#  't',
#  'a',
#  ' ',
#  'S',
#  'c',
#  'i',
#  'e',
#  'n',
#  't',
#  'i',
#  's',
#  't',
#  ' ',
#  'S',
#  'a',
#  'l',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '3',
#  ' ',
#  'y',
#  'r',
#  's',
#  ' ',
#  'e',
#  'x',
#  'p',
#  'e',
#  'r',
#  'i',
#  'e',
#  'n',
#  'c',
#  'e',
#  ' ',
#  '(',
#  'b',
#  'a',
#  's',
#  'e',
#  'd',
#  ' ',
#  'o',
#  'n',
#  ' ',
#  '1',
#  '2',
#  ' ',
#  's',
#  'a',
#  'l',
#  'a',
#  'r',
#  'i',
#  'e',
#  's',
#  ')',
#  'A',
#  'b',
#  ' ',
#  'I',
#  'n',
#  'b',
#  'e',
#  'v',
#  '\n',
#  'D',
#  'a',
#  't',
#  'a',
#  ' ',
#  'S',
#  'c',
#  'i',
#  'e',
#  'n',
#  't',
#  'i',
#  's',
#  't',
#  ' ',
#  'S',
#  'a',
#  'l',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '3',
#  '-',
#  '4',
#  ' ',
#  'y',
#  'r',
#  's',
#  ' ',
#  'e',
#  'x',
#  'p',
#  'e',
#  'r',
#  'i',
#  'e',
#  'n',
#  'c',
#  'e',
#  ' ',
#  '(',
#  'b',
#  'a',
#  's',
#  'e',
#  'd',
#  ' ',
#  'o',
#  'n',
#  ' ',
#  '3',
#  '3',
#  ' ',
#  's',
#  'a',
#  'l',
#  'a',
#  'r',
#  'i',
#  'e',
#  's',
#  ')',
#  'Z',
#  'S',
#  '\n',
#  'D',
#  'a',
#  't',
#  'a',
#  ' ',
#  'S',
#  'c',
#  'i',
#  'e',
#  'n',
#  't',
#  'i',
#  's',
#  't',
#  ' ',
#  'S',
#  'a',
#  'l',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '2',
#  ' ',
#  'y',
#  'r',
#  's',
#  ' ',
#  'e',
#  'x',
#  'p',
#  'e',
#  'r',
#  'i',
#  'e',
#  'n',
#  'c',
#  'e',
#  ' ',
#  '(',
#  'b',
#  'a',
#  's',
#  'e',
#  'd',
#  ' ',
#  'o',
#  'n',
#  ' ',
#  '1',
#  '5',
#  ' ',
#  's',
#  'a',
#  'l',
#  'a',
#  'r',
#  'i',
#  'e',
#  's',
#  ')',
#  'O',
#  'p',
#  't',
#  'u',
#  'm',
#  '\n',
#  'D',
#  'a',
#  't',
#  'a',
#  ' ',
#  'S',
#  'c',
#  'i',
#  'e',
#  'n',
#  't',
#  'i',
#  's',
#  't',
#  ' ',
#  'S',
#  'a',
#  'l',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '3',
#  '-',
#  '4',
#  ' ',
#  'y',
#  'r',
#  's',
#  ' ',
#  'e',
#  'x',
#  'p',
#  'e',
#  'r',
#  'i',
#  'e',
#  'n',
#  'c',
#  'e',
#  ' ',
#  '(',
#  'b',
#  'a',
#  's',
#  'e',
#  'd',
#  ' ',
#  'o',
#  'n',
#  ' ',
#  '3',
#  '2',
#  ' ',
#  's',
#  'a',
#  'l',
#  'a',
#  'r',
#  'i',
#  'e',
#  's',
#  ')',
#  'R',
#  'e',
#  'l',
#  'i',
#  'a',
#  'n',
#  'c',
#  'e',
#  ' ',
#  'J',
#  'i',
#  'o',
#  '\n',
#  'D',
#  'a',
#  't',
#  'a',
#  ' ',
#  'S',
#  'c',
#  'i',
#  'e',
#  'n',
#  't',
#  'i',
#  's',
#  't',
#  ' ',
#  'S',
#  'a',
#  'l',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '3',
#  '-',
#  '4',
#  ' ',
#  'y',
#  'r',
#  's',
#  ' ',
#  'e',
#  'x',
#  'p',
#  'e',
#  'r',
#  'i',
#  'e',
#  'n',
#  'c',
#  'e',
#  ' ',
#  '(',
#  'b',
#  'a',
#  's',
#  'e',
#  'd',
#  ' ',
#  'o',
#  'n',
#  ' ',
#  '2',
#  '1',
#  ' ',
#  's',
#  'a',
#  'l',
#  'a',
#  'r',
#  'i',
#  'e',
#  's',
#  ')',
#  'F',
#  'r',
#  'a',
#  'c',
#  't',
#  'a',
#  'l',
#  ' ',
#  'A',
#  'n',
#  'a',
#  'l',
#  'y',
#  't',
#  'i',
#  'c',
#  's',
#  '\n',
#  'D',
#  'a',
#  't',
#  'a',
#  ' ',
#  'S',
#  'c',
#  'i',
#  'e',
#  'n',
#  't',
#  'i',
#  's',
#  't',
#  ' ',
#  'S',
#  'a',
#  'l',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '2',
#  '-',
#  '4',
#  ' ',
#  'y',
#  'r',
#  's',
#  ' ',
#  'e',
#  'x',
#  'p',
#  'e',
#  'r',
#  'i',
#  'e',
#  'n',
#  'c',
#  'e',
#  ' ',
#  '(',
#  'b',
#  'a',
#  's',
#  'e',
#  'd',
#  ' ',
#  'o',
#  'n',
#  ' ',
#  '8',
#  '9',
#  ' ',
#  's',
#  'a',
#  'l',
#  'a',
#  'r',
#  'i',
#  'e',
#  's',
#  ')',
#  'T',
#  'i',
#  'g',
#  'e',
#  'r',
#  ' ',
#  'A',
#  'n',
#  'a',
#  'l',
#  'y',
#  't',
#  'i',
#  'c',
#  's',
#  '\n',
#  'D',
#  'a',
#  't',
#  'a',
#  ' ',
#  'S',
#  'c',
#  'i',
#  'e',
#  'n',
#  't',
#  'i',
#  's',
#  't',
#  ' ',
#  'S',
#  'a',
#  'l',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '2',
#  '-',
#  '4',
#  ' ',
#  'y',
#  'r',
#  's',
#  ' ',
#  'e',
#  'x',
#  'p',
#  'e',
#  'r',
#  'i',
#  'e',
#  'n',
#  'c',
#  'e',
#  ' ',
#  '(',
#  'b',
#  'a',
#  's',
#  'e',
#  'd',
#  ' ',
#  'o',
#  'n',
#  ' ',
#  '5',
#  '1',
#  ' ',
#  's',
#  'a',
#  'l',
#  'a',
#  'r',
#  'i',
#  'e',
#  's',
#  ')',
#  'U',
#  'n',
#  'i',
#  't',
#  'e',
#  'd',
#  'H',
#  'e',
#  'a',
#  'l',
#  't',
#  'h',
#  '\n',
#  'D',
#  'a',
#  't',
#  'a',
#  ' ',
#  'S',
#  'c',
#  'i',
#  'e',
#  'n',
#  't',
#  'i',
#  's',
#  't',
#  ' ',
#  'S',
#  'a',
#  'l',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '2',
#  '-',
#  '4',
#  ' ',
#  'y',
#  'r',
#  's',
#  ' ',
#  'e',
#  'x',
#  'p',
#  'e',
#  'r',
#  'i',
#  'e',
#  'n',
#  'c',
#  'e',
#  ' ',
#  '(',
#  'b',
#  'a',
#  's',
#  'e',
#  'd',
#  ' ',
#  'o',
#  'n',
#  ' ',
#  '5',
#  '7',
#  ' ',
#  's',
#  'a',
#  'l',
#  'a',
#  'r',
#  'i',
#  'e',
#  's',
#  ')',
#  'E',
#  'X',
#  'L',
#  ' ',
#  'S',
#  'e',
#  'r',
#  'v',
#  'i',
#  'c',
#  'e',
#  '\n',
#  'D',
#  'a',
#  't',
#  'a',
#  ' ',
#  'S',
#  'c',
#  'i',
#  'e',
#  'n',
#  't',
#  'i',
#  's',
#  't',
#  ' ',
#  'S',
#  'a',
#  'l',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '3',
#  '-',
#  '4',
#  ' ',
#  'y',
#  'r',
#  's',
#  ' ',
#  'e',
#  'x',
#  'p',
#  'e',
#  'r',
#  'i',
#  'e',
#  'n',
#  'c',
#  'e',
#  ' ',
#  '(',
#  'b',
#  'a',
#  's',
#  'e',
#  'd',
#  ' ',
#  'o',
#  'n',
#  ' ',
#  '2',
#  '1',
#  ' ',
#  's',
#  'a',
#  'l',
#  'a',
#  'r',
#  'i',
#  'e',
#  's',
#  ')',
#  'D',
#  'e',
#  'l',
#  'o',
#  'i',
#  't',
#  't',
#  'e',
#  '\n',
#  'D',
#  'a',
#  't',
#  'a',
#  ' ',
#  'S',
#  'c',
#  'i',
#  'e',
#  'n',
#  't',
#  'i',
#  's',
#  't',
#  ' ',
#  'S',
#  'a',
#  'l',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '2',
#  '-',
#  '4',
#  ' ',
#  'y',
#  'r',
#  's',
#  ' ',
#  'e',
#  'x',
#  'p',
#  'e',
#  'r',
#  'i',
#  'e',
#  'n',
#  'c',
#  'e',
#  ' ',
#  '(',
#  'b',
#  'a',
#  's',
#  'e',
#  'd',
#  ' ',
#  'o',
#  'n',
#  ' ',
#  '6',
#  '9',
#  ' ',
#  's',
#  'a',
#  'l',
#  'a',
#  'r',
#  'i',
#  'e',
#  's',
#  ')']
